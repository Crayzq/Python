# %%
import pandas as pd

#read excel into jupyter notebook, change the file name will do.
SBM_CPD_2021 = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_2021_fullgc_2021-12-31-16-10-33.csv')
SBM_CPD_ADVERT_MARKET = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_ADVERT_MARKET_fullgc_2021-12-31-16-08-14.csv')
SBM_CPD_AML = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_AML_fullgc_2021-12-31-16-09-11.csv')
SBM_CPD_CORP_GOVERN = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_CORP_GOVERN_fullgc_2021-12-31-16-09-40.csv')
SBM_CPD_CYBER_RESIL = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_CYBER_RESIL_fullgc_2021-12-31-16-11-25.csv')
SBM_CPD_ETHICS = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_ETHICS_fullgc_2021-12-31-16-09-53.csv')
SBM_CPD_GUIDELINES = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_GUIDELINES_fullgc_2021-12-31-16-11-39.csv')
SBM_CPD_LRM = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_LRM_fullgc_2021-12-31-16-10-52.csv')
SBM_CPD_MART_ABUSE = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_MART_ABUSE_fullgc_2021-12-31-16-11-03.csv')
SBM_CPD_MAS_REGN = pd.read_csv (r'C:\Users\raymondc\Desktop\Imas_Report\gc_SBM_CPD_MAS_REGN_fullgc_2021-12-31-16-10-19.csv')

master_file = pd.read_excel (r'C:\Users\raymondc\Desktop\Imas_Report\Master_IMAS_Submission.xls')

################ Start of code to merge the data for all reports with the master file ################

#SBM_CPD_2021
SBM_CPD_2021 = pd.merge(SBM_CPD_2021,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_2021 = SBM_CPD_2021.dropna(axis=0, how='any', subset= ['INVESTMENT MANAGEMENT - ETHICS RULES AND REGULATIONS SBM_CPD_2021'])
SBM_CPD_2021.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_2021 = SBM_CPD_2021.reset_index()

#SBM_CPD_ADVERT_MARKET
SBM_CPD_ADVERT_MARKET = pd.merge(SBM_CPD_ADVERT_MARKET,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_ADVERT_MARKET = SBM_CPD_ADVERT_MARKET.dropna(axis=0, how='any', subset= ['ADVERTISING AND MARKETING FOR RETAIL FUND MANAGEMENT COMPANIES (C8) SBM_CPD_ADVERT_MARKET'])
SBM_CPD_ADVERT_MARKET.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_ADVERT_MARKET = SBMs_CPD_ADVERT_MARKET.reset_index()

#SBM_CPD_AML
SBM_CPD_AML = pd.merge(SBM_CPD_AML,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_AML = SBM_CPD_AML.dropna(axis=0, how='any', subset= ['ANTI MONEY LAUNDERING AND COUNTERING THE FINANCING OF TERRORISM (C1) SBM_CPD_AML'])
SBM_CPD_AML.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_AML = SBM_CPD_AML.reset_index()

#SBM_CPD_CORP_GOVERN
SBM_CPD_CORP_GOVERN = pd.merge(SBM_CPD_CORP_GOVERN,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_CORP_GOVERN = SBM_CPD_CORP_GOVERN.dropna(axis=0, how='any', subset= ['CORPORATE GOVERNANCE FOR FUND MANAGERS AND THE SENIOR MANAGEMENT INDIVIDUAL ACCOUNTABILITY REGIME (C2) SBM_CPD_CORP_GOVERN'])
SBM_CPD_CORP_GOVERN.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_CORP_GOVERN = SBM_CPD_CORP_GOVERN.reset_index()

#SBM_CPD_CYBER_RESIL
SBM_CPD_CYBER_RESIL = pd.merge(SBM_CPD_CYBER_RESIL,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_CYBER_RESIL = SBM_CPD_CYBER_RESIL.dropna(axis=0, how='any', subset= ['STRENGTHENING CYBER RESILIENCE SINGAPORE (C6) SBM_CPD_CYBER_RESIL'])
SBM_CPD_CYBER_RESIL.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_CYBER_RESIL = SBM_CPD_CYBER_RESIL.reset_index()

#SBM_CPD_ETHICS
SBM_CPD_ETHICS = pd.merge(SBM_CPD_ETHICS,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_ETHICS = SBM_CPD_ETHICS.dropna(axis=0, how='any', subset= ['ETHICS IN THE FINANCIAL INDUSTRY (C3) SBM_CPD_ETHICS'])
SBM_CPD_ETHICS.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_ETHICS = SBM_CPD_ETHICS.reset_index()

#SBM_CPD_GUIDELINES
SBM_CPD_GUIDELINES = pd.merge(SBM_CPD_GUIDELINES,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_GUIDELINES = SBM_CPD_GUIDELINES.dropna(axis=0, how='any', subset= ['SUSTAINABLE INVESTING & MAS ENVIRONMENTAL RISK MANAGEMENT GUIDELINES (C9) SBM_CPD_GUIDELINES'])
SBM_CPD_GUIDELINES.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_GUIDELINES = SBM_CPD_GUIDELINES.reset_index()

#SBM_CPD_LRM
SBM_CPD_LRM = pd.merge(SBM_CPD_LRM,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_LRM = SBM_CPD_LRM.dropna(axis=0, how='any', subset= ['LIQUIDITY RISK MANAGEMENT  (C7) SBM_CPD_LRM'])
SBM_CPD_LRM.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_LRM = SBM_CPD_LRM.reset_index()

#SBM_CPD_MART_ABUSE
SBM_CPD_MART_ABUSE = pd.merge(SBM_CPD_MART_ABUSE,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_MART_ABUSE = SBM_CPD_MART_ABUSE.dropna(axis=0, how='any', subset= ['MARKET ABUSE IN SINGAPORE (C5) SBM_CPD_MART_ABUSE'])
SBM_CPD_MART_ABUSE.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_MART_ABUSE = SBM_CPD_MART_ABUSE.reset_index()

#SBM_CPD_MAS_REGN
SBM_CPD_MAS_REGN = pd.merge(SBM_CPD_MAS_REGN,master_file, left_on = 'First Name', right_on = 'Full Name', how='left')
#This is to drop rows with NA data
SBM_CPD_MAS_REGN = SBM_CPD_MAS_REGN.dropna(axis=0, how='any', subset= ['INTRODUCTION TO MAS REGULATION FOR FUND MANAGERS (C4) SBM_CPD_MAS_REGN'])
SBM_CPD_MAS_REGN.drop_duplicates(subset=['First Name'], keep='last', inplace=True)
SBM_CPD_MAS_REGN = SBM_CPD_MAS_REGN.reset_index()

################ End of code to merge the data for all reports with the master file ################

#This is to drop the index coulumn before the Last Name column which is an irrelevant data
SBM_CPD_2021.drop(SBM_CPD_2021.columns[0], axis=1, inplace=True)
SBM_CPD_ADVERT_MARKET.drop(SBM_CPD_ADVERT_MARKET.columns[0], axis=1, inplace=True)
SBM_CPD_AML.drop(SBM_CPD_AML.columns[0], axis=1, inplace=True)
SBM_CPD_CORP_GOVERN.drop(SBM_CPD_CORP_GOVERN.columns[0], axis=1, inplace=True)
SBM_CPD_CYBER_RESIL.drop(SBM_CPD_CYBER_RESIL.columns[0], axis=1, inplace=True)
SBM_CPD_ETHICS.drop(SBM_CPD_ETHICS.columns[0], axis=1, inplace=True)
SBM_CPD_GUIDELINES.drop(SBM_CPD_GUIDELINES.columns[0], axis=1, inplace=True)
SBM_CPD_LRM.drop(SBM_CPD_LRM.columns[0], axis=1, inplace=True)
SBM_CPD_MART_ABUSE.drop(SBM_CPD_MART_ABUSE.columns[0], axis=1, inplace=True)
SBM_CPD_MAS_REGN.drop(SBM_CPD_MAS_REGN.columns[0], axis=1, inplace=True)

#Define a function to reposition column order, no change needed.
def movecol(df, cols_to_move=[], ref_col='', place='After'):
    
    cols = df.columns.tolist()
    if place == 'After':
        seg1 = cols[:list(cols).index(ref_col) + 1]
        seg2 = cols_to_move
    if place == 'Before':
        seg1 = cols[:list(cols).index(ref_col)]
        seg2 = cols_to_move + [ref_col]
    
    seg1 = [i for i in seg1 if i not in seg2]
    seg3 = [i for i in cols if i not in seg1 + seg2]
    
    return(df[seg1 + seg2 + seg3])

#Call the movecol function to reposition company column beside first name column
SBM_CPD_2021 = movecol (SBM_CPD_2021,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_ADVERT_MARKET = movecol (SBM_CPD_ADVERT_MARKET,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_AML = movecol (SBM_CPD_AML,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_CORP_GOVERN = movecol (SBM_CPD_CORP_GOVERN,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_CYBER_RESIL = movecol (SBM_CPD_CYBER_RESIL,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_ETHICS = movecol (SBM_CPD_ETHICS,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_GUIDELINES = movecol (SBM_CPD_GUIDELINES,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_LRM = movecol (SBM_CPD_LRM,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_MART_ABUSE = movecol (SBM_CPD_MART_ABUSE,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')
SBM_CPD_MAS_REGN = movecol (SBM_CPD_MAS_REGN,cols_to_move = ['Company'], ref_col = 'First Name', place = 'After')

#First : in the loc function means, to select all the rows from the dataframe
#:'specific_column' – means select columns from the first column until the specific_column
SBM_CPD_2021 = SBM_CPD_2021.loc[:, :'Strengthening Cyber Resilience Singapore [Total Pts: 1 Complete/Incomplete] |1727254']
SBM_CPD_ADVERT_MARKET = SBM_CPD_ADVERT_MARKET.loc[:, :'Total [Total Pts: up to 200 IBF] |1742816']
SBM_CPD_AML = SBM_CPD_AML.loc[:, :'Total [Total Pts: up to 601 Score] |1598075']
SBM_CPD_CORP_GOVERN = SBM_CPD_CORP_GOVERN.loc[:, :'Total [Total Pts: up to 601 Score] |1598071']
SBM_CPD_CYBER_RESIL = SBM_CPD_CYBER_RESIL.loc[:, :'Total [Total Pts: up to 601 Score] |1598077']
SBM_CPD_ETHICS = SBM_CPD_ETHICS.loc[:, :'Total [Total Pts: up to 601 Score] |1598067']
SBM_CPD_GUIDELINES = SBM_CPD_GUIDELINES.loc[:, :'Total [Total Pts: up to 101 Score] |1861171']
SBM_CPD_LRM = SBM_CPD_LRM.loc[:, :'Total [Total Pts: up to 600 Score] |1598079']
SBM_CPD_MART_ABUSE = SBM_CPD_MART_ABUSE.loc[:, :'Total [Total Pts: up to 601 Score] |1598069']
SBM_CPD_MAS_REGN = SBM_CPD_MAS_REGN.loc[:, :'Total [Total Pts: up to 601 Score] |1598073']

#Export all reports to CSV file
SBM_CPD_2021.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_2021.csv')
SBM_CPD_ADVERT_MARKET.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_ADVERT_MARKET.csv')
SBM_CPD_AML.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_AML.csv')
SBM_CPD_CORP_GOVERN.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_CORP_GOVERN.csv')
SBM_CPD_CYBER_RESIL.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_CYBER_RESIL.csv')
SBM_CPD_ETHICS.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_ETHICS.csv')
SBM_CPD_GUIDELINES.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_GUIDELINES.csv')
SBM_CPD_LRM.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_LRM.csv')
SBM_CPD_MART_ABUSE.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_MART_ABUSE.csv')
SBM_CPD_MAS_REGN.to_csv(r'C:\Users\raymondc\Desktop\Imas_Report\Report_for_IMAS\SBM_CPD_MAS_REGN.csv')

# %%
# This is to check if the merged reports tally with the blackboard reports
#Step 1: Remove the # infront of the dataframe name and click on "Run" above
#Step 2: Can only run one dataframe at once
#Step 3: Place the # back to the report name and repeat Step 1 again to check for other data

#SBM_CPD_2021
#SBM_CPD_ADVERT_MARKET
#SBM_CPD_AML
#SBM_CPD_CORP_GOVERN
#SBM_CPD_CYBER_RESIL
#SBM_CPD_ETHICS
#SBM_CPD_GUIDELINES
#SBM_CPD_LRM
#SBM_CPD_MART_ABUSE
#SBM_CPD_MAS_REGN
